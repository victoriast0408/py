# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
filials = pd.read_excel("report_filialstat_jan2016.xlsx", na_filter=False)
filials
# Out:
#          Datum          Bezeichnung      Umsatz  <Leeren Datensatz>  \
# 0  Januar 2016       Bahnhofstrasse   72,046.30
# 1  Januar 2016  Deaktivierte Kassen   51,421.60
# 2  Januar 2016  Deaktivierte Kassen   18,671.70
# 3  Januar 2016  Deaktivierte Kassen  114,332.45
# 4  Januar 2016             Immensee
# 5  Januar 2016           Marktgasse   59,833.80
# 6  Januar 2016           Marktgasse   13,425.45
# 7  Januar 2016                Messe   62,645.55
# 8                                    392,376.85                   .
#
#    <Leeren Datensatz>.1  <Leeren Datensatz>.2  <Leeren Datensatz>.3  \
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8                     .                     .                     .
#
#   00002 Test 1000 Brot Gross 1010 Kleinbrot  ... Umsatz Kundenkarte  \
# 0                     894.10                 ...           5,746.75
# 1                       6.60                 ...           3,703.50
# 2                                 10,544.30  ...           4,949.25
# ...

# %%
plt.plot(filials.Bezeichnung, filials.Umsatz)
plt.show()

# %%
plt.hist(filials.Umsatz)
plt.show()

# %%
filials['Bezeichnung']
# Out:
# 0         Bahnhofstrasse
# 1    Deaktivierte Kassen
# 2    Deaktivierte Kassen
# 3    Deaktivierte Kassen
# 4               Immensee
# 5             Marktgasse
# 6             Marktgasse
# 7                  Messe
# 8
# Name: Bezeichnung, dtype: object

# %%
filials.columns = filials.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

filials
labels= filials.umsatz_pro_anzahl_kundenkarten
plt.pie(filials.umsatz_pro_anzahl_kundenkarten, labels=labels)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-ae9d2ab8ad76> in <module>
#       3 filials
#       4 labels= filials.umsatz_pro_anzahl_kundenkarten
# ----> 5 plt.pie(filials.umsatz_pro_anzahl_kundenkarten, labels=labels)
#       6 plt.show()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2785         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2786         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2787         data is not None else {}))
#    2788
#    2789
#
# ...
